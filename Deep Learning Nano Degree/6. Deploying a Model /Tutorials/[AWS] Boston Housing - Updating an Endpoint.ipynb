# %% [markdown]
# # Predicting Boston Housing Prices
#
# ## Updating a model using SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this notebook, we will continue working with the [Boston Housing Dataset](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html). Our goal in this notebook will be to train two different models and to use SageMaker to switch a deployed endpoint from using one model to the other. One of the benefits of using SageMaker to do this is that we can make the change without interrupting service. What this means is that we can continue sending data to the endpoint and at no point will that endpoint disappear.
#
# ## General Outline
#
# Typically, when using a notebook instance with SageMaker, you will proceed through the following steps. Of course, not every step will need to be done with each project. Also, there is quite a lot of room for variation in many of the steps, as you will see throughout these lessons.
#
# 1. Download or otherwise retrieve the data.
# 2. Process / Prepare the data.
# 3. Upload the processed data to S3.
# 4. Train a chosen model.
# 5. Test the trained model (typically using a batch transform job).
# 6. Deploy the trained model.
# 7. Use the deployed model.
#
# In this notebook we will be skipping step 5, testing the model. In addition, we will perform steps 4, 6 and 7 multiple times with different models.

# %% [markdown]
# ## Step 0: Setting up the notebook
#
# We begin by setting up all of the necessary bits required to run our notebook. To start that means loading all of the Python modules we will need.

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd

from pprint import pprint
import matplotlib.pyplot as plt
from time import gmtime, strftime

from sklearn.datasets import load_boston
import sklearn.model_selection

# %% [markdown]
# In addition to the modules above, we need to import the various bits of SageMaker that we will be using.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer

# This is an object that represents the SageMaker session that we are currently operating in. This
# object contains some useful information that we will need to access later such as our region.
session = sagemaker.Session()

# This is an object that represents the IAM role that we are currently assigned. When we construct
# and launch the training job later we will need to tell it what IAM role it should have. Since our
# use case is relatively simple we will simply assign the training job the role we currently have.
role = get_execution_role()

# %% [markdown]
# ## Step 1: Downloading the data
#
# Fortunately, this dataset can be retrieved using sklearn and so this step is relatively straightforward.

# %%
boston = load_boston()

# %% [markdown]
# ## Step 2: Preparing and splitting the data
#
# Given that this is clean tabular data, we don't need to do any processing. However, we do need to split the rows in the dataset up into train, test and validation sets.

# %%
# First we package up the input data and the target variable (the median value) as pandas dataframes. This
# will make saving the data to a file a little easier later on.

X_bos_pd = pd.DataFrame(boston.data, columns=boston.feature_names)
Y_bos_pd = pd.DataFrame(boston.target)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X_bos_pd, Y_bos_pd, test_size=0.33)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %% [markdown]
# ## Step 3: Uploading the training and validation files to S3
#
# When a training job is constructed using SageMaker, a container is executed which performs the training operation. This container is given access to data that is stored in S3. This means that we need to upload the data we want to use for training to S3. We can use the SageMaker API to do this and hide some of the details.
#
# ### Save the data locally
#
# First we need to create the train and validation csv files which we will then upload to S3.

# %%
# This is our local data directory. We need to make sure that it exists.
data_dir = '../data/boston'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# We use pandas to save our train and validation data to csv files. Note that we make sure not to include header
# information or an index as this is required by the built in algorithms provided by Amazon. Also, it is assumed
# that the first entry in each row is the target variable.

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %% [markdown]
# ### Upload to S3
#
# Since we are currently running inside of a SageMaker session, we can use the object which represents this session to upload our data to the 'default' S3 bucket. Note that it is good practice to provide a custom prefix (essentially an S3 folder) to make sure that you don't accidentally interfere with data uploaded from some other notebook or project.

# %%
prefix = 'boston-update-endpoints'

val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ## Step 4 (A): Train the XGBoost model
#
# Now that we have the training and validation data uploaded to S3, we can construct our XGBoost model and train it. We will be making use of the high level SageMaker API to do this which will make the resulting code a little easier to read at the cost of some flexibility.
#
# To construct an estimator, the object which we wish to train, we need to provide the location of a container which contains the training code. Since we are using a built in algorithm this container is provided by Amazon. However, the full name of the container is a bit lengthy and depends on the region that we are operating in. Fortunately, SageMaker provides a useful utility method called `get_image_uri` that constructs the image name for us.
#
# To use the `get_image_uri` method we need to provide it with our current region, which can be obtained from the session object, and the name of the algorithm we wish to use. In this notebook we will be using XGBoost however you could try another algorithm if you wish. The list of built in algorithms can be found in the list of [Common Parameters](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
# As stated above, we use this utility method to construct the image name for the training container.
xgb_container = get_image_uri(session.boto_region_name, 'xgboost')

# Now that we know which container to use, we can construct the estimator object.
xgb = sagemaker.estimator.Estimator(xgb_container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Before asking SageMaker to begin the training job, we should probably set any model specific hyperparameters. There are quite a few that can be set when using the XGBoost algorithm, below are just a few of them. If you would like to change the hyperparameters below or modify additional ones you can find additional information on the [XGBoost hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html)

# %%
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

# %% [markdown]
# Now that we have our estimator object completely set up, it is time to train it. To do this we make sure that SageMaker knows our input data is in csv format and then execute the `fit` method.

# %%
# This is a wrapper around the location of our train and validation data, to make sure that SageMaker
# knows our data is in csv format.
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-10-30 19:18:03 Starting - Starting the training job...
# 2020-10-30 19:18:06 Starting - Launching requested ML instances......
# 2020-10-30 19:19:15 Starting - Preparing the instances for training......
# 2020-10-30 19:20:28 Downloading - Downloading input data
# 2020-10-30 19:20:28 Training - Downloading the training image...
# 2020-10-30 19:21:00 Uploading - Uploading generated training model
# 2020-10-30 19:21:00 Completed - Training job completed
# Arguments: train
# [2020-10-30:19:20:48:INFO] Running standalone xgboost training.
# [2020-10-30:19:20:48:INFO] File size need to be processed in the node: 0.02mb. Available memory size in the node: 8488.5mb
# [2020-10-30:19:20:48:INFO] Determined delimiter of CSV input is ','
# [19:20:48] S3DistributionType set as FullyReplicated
# [19:20:48] 227x13 matrix with 2951 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-10-30:19:20:48:INFO] Determined delimiter of CSV input is ','
# [19:20:48] S3DistributionType set as FullyReplicated
# [19:20:48] 112x13 matrix with 1456 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:19.5258#011validation-rmse:20.6608
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:15.9124#011validation-rmse:17.099
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [2]#011train-rmse:13.0692#011validation-rmse:14.3179
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [3]#011train-rmse:10.7602#011validation-rmse:11.9361
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [4]#011train-rmse:8.89598#011validation-rmse:10.1399
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [5]#011train-rmse:7.46654#011validation-rmse:8.81434
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [6]#011train-rmse:6.29746#011validation-rmse:7.69183
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-rmse:5.40226#011validation-rmse:6.96493
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [8]#011train-rmse:4.65409#011validation-rmse:6.24117
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [9]#011train-rmse:4.08474#011validation-rmse:5.76814
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:3.61472#011validation-rmse:5.35132
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [11]#011train-rmse:3.24375#011validation-rmse:5.05382
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:2.96351#011validation-rmse:4.8974
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:2.72296#011validation-rmse:4.67271
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:2.55279#011validation-rmse:4.56145
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:2.41549#011validation-rmse:4.49157
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [16]#011train-rmse:2.31062#011validation-rmse:4.38662
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [17]#011train-rmse:2.23932#011validation-rmse:4.33659
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [18]#011train-rmse:2.14993#011validation-rmse:4.28006
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [19]#011train-rmse:2.0648#011validation-rmse:4.25141
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [20]#011train-rmse:2.02603#011validation-rmse:4.2629
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [21]#011train-rmse:1.98771#011validation-rmse:4.22383
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [22]#011train-rmse:1.94708#011validation-rmse:4.20565
# [23]#011train-rmse:1.90866#011validation-rmse:4.17017
# [24]#011train-rmse:1.87743#011validation-rmse:4.18051
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [25]#011train-rmse:1.86664#011validation-rmse:4.20527
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [26]#011train-rmse:1.83495#011validation-rmse:4.16109
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [27]#011train-rmse:1.80073#011validation-rmse:4.11415
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [28]#011train-rmse:1.76593#011validation-rmse:4.09326
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [29]#011train-rmse:1.72304#011validation-rmse:4.09018
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [30]#011train-rmse:1.68897#011validation-rmse:4.09575
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [31]#011train-rmse:1.64228#011validation-rmse:4.0669
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [32]#011train-rmse:1.58376#011validation-rmse:4.03333
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [33]#011train-rmse:1.54498#011validation-rmse:3.99381
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [34]#011train-rmse:1.52133#011validation-rmse:3.98249
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [35]#011train-rmse:1.50398#011validation-rmse:3.95747
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [36]#011train-rmse:1.47588#011validation-rmse:3.94449
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [37]#011train-rmse:1.45277#011validation-rmse:3.93126
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 4 pruned nodes, max_depth=5
# [38]#011train-rmse:1.41415#011validation-rmse:3.90039
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [39]#011train-rmse:1.39896#011validation-rmse:3.89015
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=4
# [40]#011train-rmse:1.36068#011validation-rmse:3.87432
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=4
# [41]#011train-rmse:1.3196#011validation-rmse:3.85716
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [42]#011train-rmse:1.27179#011validation-rmse:3.86646
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [43]#011train-rmse:1.26381#011validation-rmse:3.87857
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=4
# [44]#011train-rmse:1.25201#011validation-rmse:3.87391
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [45]#011train-rmse:1.21936#011validation-rmse:3.86711
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [46]#011train-rmse:1.21492#011validation-rmse:3.85655
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [47]#011train-rmse:1.20085#011validation-rmse:3.86717
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [48]#011train-rmse:1.17129#011validation-rmse:3.84756
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [49]#011train-rmse:1.15479#011validation-rmse:3.84001
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [50]#011train-rmse:1.13238#011validation-rmse:3.81064
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [51]#011train-rmse:1.11611#011validation-rmse:3.79657
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 14 pruned nodes, max_depth=2
# [52]#011train-rmse:1.09911#011validation-rmse:3.79113
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [53]#011train-rmse:1.08562#011validation-rmse:3.78315
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [54]#011train-rmse:1.06949#011validation-rmse:3.77828
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [55]#011train-rmse:1.05551#011validation-rmse:3.77491
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [56]#011train-rmse:1.01706#011validation-rmse:3.7745
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=3
# [57]#011train-rmse:1.00741#011validation-rmse:3.7591
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [58]#011train-rmse:0.994253#011validation-rmse:3.7562
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [59]#011train-rmse:0.982826#011validation-rmse:3.76528
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [60]#011train-rmse:0.962664#011validation-rmse:3.74712
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [61]#011train-rmse:0.96259#011validation-rmse:3.74701
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [62]#011train-rmse:0.962563#011validation-rmse:3.74696
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [63]#011train-rmse:0.944001#011validation-rmse:3.75229
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [64]#011train-rmse:0.929965#011validation-rmse:3.74021
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [65]#011train-rmse:0.929966#011validation-rmse:3.7402
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 18 pruned nodes, max_depth=1
# [66]#011train-rmse:0.931185#011validation-rmse:3.73795
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 10 pruned nodes, max_depth=2
# [67]#011train-rmse:0.928418#011validation-rmse:3.7367
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [68]#011train-rmse:0.927195#011validation-rmse:3.73993
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [69]#011train-rmse:0.922393#011validation-rmse:3.74799
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [70]#011train-rmse:0.922365#011validation-rmse:3.74792
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [71]#011train-rmse:0.904633#011validation-rmse:3.73928
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [72]#011train-rmse:0.904663#011validation-rmse:3.73935
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [73]#011train-rmse:0.889957#011validation-rmse:3.73866
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [74]#011train-rmse:0.881242#011validation-rmse:3.74301
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [75]#011train-rmse:0.881296#011validation-rmse:3.74328
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 28 pruned nodes, max_depth=3
# [76]#011train-rmse:0.875494#011validation-rmse:3.74546
# [19:20:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [77]#011train-rmse:0.866192#011validation-rmse:3.75962
# Stopping. Best iteration:
# [67]#011train-rmse:0.928418#011validation-rmse:3.7367
#
# Training seconds: 47
# Billable seconds: 47

# %% [markdown]
# ## Step 5: Test the trained model
#
# We will be skipping this step for now.
#
#
# ## Step 6 (A): Deploy the trained model
#
# Even though we used the high level approach to construct and train the XGBoost model, we will be using the lower level approach to deploy it. One of the reasons for this is so that we have additional control over how the endpoint is constructed. This will be a little more clear later on when construct more advanced endpoints.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# Remember that a model needs to have a unique name
xgb_model_name = "boston-update-xgboost-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the xgboost container that we used for training
# can also be used for inference and the model artifacts come from the previous call to fit.
xgb_primary_container = {
    "Image": xgb_container,
    "ModelDataUrl": xgb.model_data
}

# And lastly we construct the SageMaker model
xgb_model_info = session.sagemaker_client.create_model(
                                ModelName = xgb_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = xgb_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have a model we can start putting together the endpoint. Recall that to do this we need to first create an endpoint configuration, essentially the blueprint that SageMaker will use to build the endpoint itself.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
xgb_endpoint_config_name = "boston-update-xgboost-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
xgb_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = xgb_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": xgb_model_name,
                                "VariantName": "XGB-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = xgb_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------!

# %% [markdown]
# ## Step 7 (A): Use the model
#
# Now that our model is trained and deployed we can send some test data to it and evaluate the results.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f6406483860>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Fri, 30 Oct 2020 19:32:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'f698b77b-7c96-41fb-a99e-a04253e4620a'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'f698b77b-7c96-41fb-a99e-a04253e4620a',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '21.6027011871'

# %%
Y_test.values[0]
# Out:
# array([20.9])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the XGBoost endpoint works, we can shut it down. We will make use of it again later.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '6b3ba07a-644b-40d9-9469-5255dc1db158',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6b3ba07a-644b-40d9-9469-5255dc1db158',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Fri, 30 Oct 2020 19:32:38 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 4 (B): Train the Linear model
#
# Suppose we are working in an environment where the XGBoost model that we trained earlier is becoming too costly. Perhaps the number of calls to our endpoint has increased and the length of time it takes to perform inference with the XGBoost model is becoming problematic.
#
# A possible solution might be to train a simpler model to see if it performs nearly as well. In our case, we will construct a linear model. The process of doing this is the same as for creating the XGBoost model that we created earlier, although there are different hyperparameters that we need to set.

# %%
# Similar to the XGBoost model, we will use the utility method to construct the image name for the training container.
linear_container = get_image_uri(session.boto_region_name, 'linear-learner')

# Now that we know which container to use, we can construct the estimator object.
linear = sagemaker.estimator.Estimator(linear_container, # The name of the training container
                                        role,      # The IAM role to use (our current role in this case)
                                        train_instance_count=1, # The number of instances to use for training
                                        train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                        output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                            # Where to save the output (the model artifacts)
                                        sagemaker_session=session) # The current SageMaker session
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Before asking SageMaker to train our model, we need to set some hyperparameters. In this case we will be using a linear model so the number of hyperparameters we need to set is much fewer. For more details see the [Linear model hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html)

# %%
linear.set_hyperparameters(feature_dim=13, # Our data has 13 feature columns
                           predictor_type='regressor', # We wish to create a regression model
                           mini_batch_size=200) # Here we set how many samples to look at in each iteration

# %% [markdown]
# Now that the hyperparameters have been set, we can ask SageMaker to fit the linear model to our data.

# %%
linear.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-10-30 19:32:44 Starting - Starting the training job...
# 2020-10-30 19:32:46 Starting - Launching requested ML instances......
# 2020-10-30 19:34:13 Starting - Preparing the instances for training......
# 2020-10-30 19:35:09 Downloading - Downloading input data...
# 2020-10-30 19:35:27 Training - Downloading the training image...
# 2020-10-30 19:36:09 Uploading - Uploading generated training model
# 2020-10-30 19:36:09 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [10/30/2020 19:36:00 INFO 139703162902336] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/30/2020 19:36:00 INFO 139703162902336] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'200', u'predictor_type': u'regressor'}
# [10/30/2020 19:36:00 INFO 139703162902336] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [10/30/2020 19:36:00 WARNING 139703162902336] Loggers have already been setup.
# Process 1 is a worker.
# [10/30/2020 19:36:00 INFO 139703162902336] Using default worker.
# [10/30/2020 19:36:00 INFO 139703162902336] Checkpoint loading and saving are disabled.
# [10/30/2020 19:36:00 INFO 139703162902336] Create Store: local
# [10/30/2020 19:36:00 INFO 139703162902336] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f0ecdd8fe90>
# [10/30/2020 19:36:00 INFO 139703162902336] Scaling model computed with parameters:
#  {'stdev_weight':
# [9.6423416e+00 2.3024181e+01 6.5524273e+00 2.0730412e-01 1.1973808e-01
#  6.8514132e-01 2.9970367e+01 2.1144512e+00 8.7771006e+00 1.6867159e+02
#  2.1247280e+00 9.5863937e+01 7.0794282e+00]
# <NDArray 13 @cpu(0)>, 'stdev_label':
# [9.180511]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [22.54]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.9699612e+00 1.1182500e+01 1.0919001e+01 4.4999998e-02 5.5534047e-01
#  6.3017802e+00 6.8187500e+01 3.8123465e+00 9.9499998e+00 4.1199500e+02
#  1.8486500e+01 3.5560388e+02 1.2368200e+01]
# <NDArray 13 @cpu(0)>}
# [10/30/2020 19:36:00 INFO 139703162902336] nvidia-smi took: 0.0252089500427 secs to identify 0 gpus
# [10/30/2020 19:36:00 INFO 139703162902336] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 3, "sum": 3.0, "min": 3}, "Total Records Seen": {"count": 1, "max": 427, "sum": 427.0, "min": 427}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1604086560.429525, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1604086560.429481}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9639254760742187, "sum": 0.9639254760742187, "min": 0.9639254760742187}}, "EndTime": 1604086560.464324, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464261}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8761438751220703, "sum": 0.8761438751220703, "min": 0.8761438751220703}}, "EndTime": 1604086560.464404, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464384}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.336443634033203, "sum": 1.336443634033203, "min": 1.336443634033203}}, "EndTime": 1604086560.464475, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464457}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8704179382324219, "sum": 0.8704179382324219, "min": 0.8704179382324219}}, "EndTime": 1604086560.464549, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.46453}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8776553344726562, "sum": 0.8776553344726562, "min": 0.8776553344726562}}, "EndTime": 1604086560.464609, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464591}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0214370727539062, "sum": 1.0214370727539062, "min": 1.0214370727539062}}, "EndTime": 1604086560.464667, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.46465}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1341970825195313, "sum": 1.1341970825195313, "min": 1.1341970825195313}}, "EndTime": 1604086560.464733, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464716}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1140126037597655, "sum": 1.1140126037597655, "min": 1.1140126037597655}}, "EndTime": 1604086560.464786, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464771}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9427586364746093, "sum": 0.9427586364746093, "min": 0.9427586364746093}}, "EndTime": 1604086560.464847, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464831}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4166473388671874, "sum": 1.4166473388671874, "min": 1.4166473388671874}}, "EndTime": 1604086560.4649, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464883}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.87173583984375, "sum": 0.87173583984375, "min": 0.87173583984375}}, "EndTime": 1604086560.464961, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.464944}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1165097045898438, "sum": 1.1165097045898438, "min": 1.1165097045898438}}, "EndTime": 1604086560.465049, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465031}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0165092468261718, "sum": 1.0165092468261718, "min": 1.0165092468261718}}, "EndTime": 1604086560.465115, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465098}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.034978790283203, "sum": 1.034978790283203, "min": 1.034978790283203}}, "EndTime": 1604086560.465184, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465166}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8944136810302734, "sum": 0.8944136810302734, "min": 0.8944136810302734}}, "EndTime": 1604086560.465246, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465229}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.022822036743164, "sum": 1.022822036743164, "min": 1.022822036743164}}, "EndTime": 1604086560.465308, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465291}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0483390808105468, "sum": 1.0483390808105468, "min": 1.0483390808105468}}, "EndTime": 1604086560.465369, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465352}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8678338623046875, "sum": 0.8678338623046875, "min": 0.8678338623046875}}, "EndTime": 1604086560.465441, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465423}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.228355712890625, "sum": 1.228355712890625, "min": 1.228355712890625}}, "EndTime": 1604086560.465512, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465494}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0356787109375, "sum": 1.0356787109375, "min": 1.0356787109375}}, "EndTime": 1604086560.465568, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465552}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7917200469970703, "sum": 0.7917200469970703, "min": 0.7917200469970703}}, "EndTime": 1604086560.465634, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465618}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1531615447998047, "sum": 1.1531615447998047, "min": 1.1531615447998047}}, "EndTime": 1604086560.465699, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.46568}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7728789520263671, "sum": 0.7728789520263671, "min": 0.7728789520263671}}, "EndTime": 1604086560.465769, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.46575}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8667601776123047, "sum": 0.8667601776123047, "min": 0.8667601776123047}}, "EndTime": 1604086560.465832, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465815}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9506597900390625, "sum": 0.9506597900390625, "min": 0.9506597900390625}}, "EndTime": 1604086560.465894, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465876}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9469211578369141, "sum": 0.9469211578369141, "min": 0.9469211578369141}}, "EndTime": 1604086560.465959, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.465942}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2287962341308594, "sum": 1.2287962341308594, "min": 1.2287962341308594}}, "EndTime": 1604086560.466032, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.466013}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.136532745361328, "sum": 1.136532745361328, "min": 1.136532745361328}}, "EndTime": 1604086560.466121, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.466102}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0271784210205077, "sum": 1.0271784210205077, "min": 1.0271784210205077}}, "EndTime": 1604086560.466171, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.466161}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9512408447265625, "sum": 0.9512408447265625, "min": 0.9512408447265625}}, "EndTime": 1604086560.46623, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.466214}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1343560791015626, "sum": 1.1343560791015626, "min": 1.1343560791015626}}, "EndTime": 1604086560.466266, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.466258}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.145490951538086, "sum": 1.145490951538086, "min": 1.145490951538086}}, "EndTime": 1604086560.466321, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.466305}
#
# [10/30/2020 19:36:00 INFO 139703162902336] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.963925476074
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 106.01176234654018, "sum": 106.01176234654018, "min": 106.01176234654018}}, "EndTime": 1604086560.510102, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510047}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 100.7584228515625, "sum": 100.7584228515625, "min": 100.7584228515625}}, "EndTime": 1604086560.510167, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510153}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 143.55260358537947, "sum": 143.55260358537947, "min": 143.55260358537947}}, "EndTime": 1604086560.51024, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510219}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 99.25016566685268, "sum": 99.25016566685268, "min": 99.25016566685268}}, "EndTime": 1604086560.51032, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510299}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.51558140345982, "sum": 84.51558140345982, "min": 84.51558140345982}}, "EndTime": 1604086560.510389, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510371}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 61.89489310128348, "sum": 61.89489310128348, "min": 61.89489310128348}}, "EndTime": 1604086560.510456, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510437}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 81.09844098772321, "sum": 81.09844098772321, "min": 81.09844098772321}}, "EndTime": 1604086560.510526, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510508}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 78.16556222098214, "sum": 78.16556222098214, "min": 78.16556222098214}}, "EndTime": 1604086560.510591, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510572}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 103.09534563337054, "sum": 103.09534563337054, "min": 103.09534563337054}}, "EndTime": 1604086560.51066, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510642}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 149.1182861328125, "sum": 149.1182861328125, "min": 149.1182861328125}}, "EndTime": 1604086560.510724, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510706}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 97.57915387834821, "sum": 97.57915387834821, "min": 97.57915387834821}}, "EndTime": 1604086560.510787, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.51077}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 124.82680838448661, "sum": 124.82680838448661, "min": 124.82680838448661}}, "EndTime": 1604086560.510852, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510834}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 82.49098423549107, "sum": 82.49098423549107, "min": 82.49098423549107}}, "EndTime": 1604086560.510914, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510898}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.296875, "sum": 83.296875, "min": 83.296875}}, "EndTime": 1604086560.510974, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.510958}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 90.6014404296875, "sum": 90.6014404296875, "min": 90.6014404296875}}, "EndTime": 1604086560.511038, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511021}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.33797345842633, "sum": 68.33797345842633, "min": 68.33797345842633}}, "EndTime": 1604086560.511105, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511087}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 116.33319091796875, "sum": 116.33319091796875, "min": 116.33319091796875}}, "EndTime": 1604086560.51118, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511161}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 96.53447614397321, "sum": 96.53447614397321, "min": 96.53447614397321}}, "EndTime": 1604086560.511245, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511228}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 138.3755841936384, "sum": 138.3755841936384, "min": 138.3755841936384}}, "EndTime": 1604086560.511309, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511291}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 117.07784598214286, "sum": 117.07784598214286, "min": 117.07784598214286}}, "EndTime": 1604086560.511373, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511355}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.62288120814732, "sum": 71.62288120814732, "min": 71.62288120814732}}, "EndTime": 1604086560.511436, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511419}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 73.65200369698661, "sum": 73.65200369698661, "min": 73.65200369698661}}, "EndTime": 1604086560.511499, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511481}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.62559291294643, "sum": 76.62559291294643, "min": 76.62559291294643}}, "EndTime": 1604086560.511563, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511545}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.90727887834821, "sum": 76.90727887834821, "min": 76.90727887834821}}, "EndTime": 1604086560.511627, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511608}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 113.33952985491071, "sum": 113.33952985491071, "min": 113.33952985491071}}, "EndTime": 1604086560.51169, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511671}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 109.91179547991071, "sum": 109.91179547991071, "min": 109.91179547991071}}, "EndTime": 1604086560.511752, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511735}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 134.97740827287947, "sum": 134.97740827287947, "min": 134.97740827287947}}, "EndTime": 1604086560.511816, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511797}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 127.26139613560268, "sum": 127.26139613560268, "min": 127.26139613560268}}, "EndTime": 1604086560.511883, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511865}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 121.92452566964286, "sum": 121.92452566964286, "min": 121.92452566964286}}, "EndTime": 1604086560.511953, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.511935}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 142.98966761997767, "sum": 142.98966761997767, "min": 142.98966761997767}}, "EndTime": 1604086560.512021, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.512003}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 109.69419642857143, "sum": 109.69419642857143, "min": 109.69419642857143}}, "EndTime": 1604086560.512086, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.512068}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 106.61528669084821, "sum": 106.61528669084821, "min": 106.61528669084821}}, "EndTime": 1604086560.512148, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.512131}
#
# [10/30/2020 19:36:00 INFO 139703162902336] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=106.011762347
# [10/30/2020 19:36:00 INFO 139703162902336] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=61.8948931013
# [10/30/2020 19:36:00 INFO 139703162902336] Epoch 0: Loss improved. Updating best model
# [10/30/2020 19:36:00 INFO 139703162902336] Saving model for epoch: 0
# [10/30/2020 19:36:00 INFO 139703162902336] Saved checkpoint to "/tmp/tmpb5olJj/mx-mod-0000.params"
# [10/30/2020 19:36:00 INFO 139703162902336] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 654, "sum": 654.0, "min": 654}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1604086560.520563, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1604086560.429774}
#
# [10/30/2020 19:36:00 INFO 139703162902336] #throughput_metric: host=algo-1, train throughput=2496.58988418 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9121165466308594, "sum": 0.9121165466308594, "min": 0.9121165466308594}}, "EndTime": 1604086560.551145, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551052}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8319838714599609, "sum": 0.8319838714599609, "min": 0.8319838714599609}}, "EndTime": 1604086560.551247, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551227}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2651292419433593, "sum": 1.2651292419433593, "min": 1.2651292419433593}}, "EndTime": 1604086560.551314, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551297}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8255191802978515, "sum": 0.8255191802978515, "min": 0.8255191802978515}}, "EndTime": 1604086560.551373, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551358}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7928294372558594, "sum": 0.7928294372558594, "min": 0.7928294372558594}}, "EndTime": 1604086560.55143, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551414}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.543807373046875, "sum": 0.543807373046875, "min": 0.543807373046875}}, "EndTime": 1604086560.551489, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551473}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7298207092285156, "sum": 0.7298207092285156, "min": 0.7298207092285156}}, "EndTime": 1604086560.551544, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551529}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6923884582519532, "sum": 0.6923884582519532, "min": 0.6923884582519532}}, "EndTime": 1604086560.551597, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551583}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8988941192626954, "sum": 0.8988941192626954, "min": 0.8988941192626954}}, "EndTime": 1604086560.55165, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551636}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3419308471679687, "sum": 1.3419308471679687, "min": 1.3419308471679687}}, "EndTime": 1604086560.551704, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.55169}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8310257720947266, "sum": 0.8310257720947266, "min": 0.8310257720947266}}, "EndTime": 1604086560.551758, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551744}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0599208068847656, "sum": 1.0599208068847656, "min": 1.0599208068847656}}, "EndTime": 1604086560.551812, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551797}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7442898559570312, "sum": 0.7442898559570312, "min": 0.7442898559570312}}, "EndTime": 1604086560.551867, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551853}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7755458068847656, "sum": 0.7755458068847656, "min": 0.7755458068847656}}, "EndTime": 1604086560.551923, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551907}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8321684265136718, "sum": 0.8321684265136718, "min": 0.8321684265136718}}, "EndTime": 1604086560.551983, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.551966}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5934568023681641, "sum": 0.5934568023681641, "min": 0.5934568023681641}}, "EndTime": 1604086560.552045, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552028}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9937191772460937, "sum": 0.9937191772460937, "min": 0.9937191772460937}}, "EndTime": 1604086560.552107, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.55209}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8295125579833984, "sum": 0.8295125579833984, "min": 0.8295125579833984}}, "EndTime": 1604086560.552166, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.55215}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1689806365966797, "sum": 1.1689806365966797, "min": 1.1689806365966797}}, "EndTime": 1604086560.552225, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552209}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9831261444091797, "sum": 0.9831261444091797, "min": 0.9831261444091797}}, "EndTime": 1604086560.552278, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552264}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6457403564453125, "sum": 0.6457403564453125, "min": 0.6457403564453125}}, "EndTime": 1604086560.552328, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552316}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6646161651611329, "sum": 0.6646161651611329, "min": 0.6646161651611329}}, "EndTime": 1604086560.552378, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552364}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7058455657958984, "sum": 0.7058455657958984, "min": 0.7058455657958984}}, "EndTime": 1604086560.552435, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.55242}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6909471893310547, "sum": 0.6909471893310547, "min": 0.6909471893310547}}, "EndTime": 1604086560.552496, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.55248}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9570700073242188, "sum": 0.9570700073242188, "min": 0.9570700073242188}}, "EndTime": 1604086560.552555, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552538}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9572730255126953, "sum": 0.9572730255126953, "min": 0.9572730255126953}}, "EndTime": 1604086560.552621, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552602}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1865179443359375, "sum": 1.1865179443359375, "min": 1.1865179443359375}}, "EndTime": 1604086560.552688, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552669}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.120108642578125, "sum": 1.120108642578125, "min": 1.120108642578125}}, "EndTime": 1604086560.552757, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552738}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0397146606445313, "sum": 1.0397146606445313, "min": 1.0397146606445313}}, "EndTime": 1604086560.552822, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552804}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2277752685546874, "sum": 1.2277752685546874, "min": 1.2277752685546874}}, "EndTime": 1604086560.55289, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552873}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9074104309082032, "sum": 0.9074104309082032, "min": 0.9074104309082032}}, "EndTime": 1604086560.552951, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.552934}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9109539794921875, "sum": 0.9109539794921875, "min": 0.9109539794921875}}, "EndTime": 1604086560.553059, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.553039}
#
# [10/30/2020 19:36:00 INFO 139703162902336] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.912116546631
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 100.48203822544643, "sum": 100.48203822544643, "min": 100.48203822544643}}, "EndTime": 1604086560.594858, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.594803}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 95.92936488560268, "sum": 95.92936488560268, "min": 95.92936488560268}}, "EndTime": 1604086560.594925, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.594912}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 136.06998988560267, "sum": 136.06998988560267, "min": 136.06998988560267}}, "EndTime": 1604086560.594968, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.594958}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 94.40987723214286, "sum": 94.40987723214286, "min": 94.40987723214286}}, "EndTime": 1604086560.595026, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595009}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 80.14281354631696, "sum": 80.14281354631696, "min": 80.14281354631696}}, "EndTime": 1604086560.595089, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595072}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 88.33727155412946, "sum": 88.33727155412946, "min": 88.33727155412946}}, "EndTime": 1604086560.595152, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595135}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 90.02791922433036, "sum": 90.02791922433036, "min": 90.02791922433036}}, "EndTime": 1604086560.595216, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595198}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 87.52427455357143, "sum": 87.52427455357143, "min": 87.52427455357143}}, "EndTime": 1604086560.59529, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595272}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 98.26411655970982, "sum": 98.26411655970982, "min": 98.26411655970982}}, "EndTime": 1604086560.595363, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595345}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 141.33869280133928, "sum": 141.33869280133928, "min": 141.33869280133928}}, "EndTime": 1604086560.595428, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595411}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 93.07856968470982, "sum": 93.07856968470982, "min": 93.07856968470982}}, "EndTime": 1604086560.59549, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595474}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 118.75072370256696, "sum": 118.75072370256696, "min": 118.75072370256696}}, "EndTime": 1604086560.595552, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595533}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 86.63364955357143, "sum": 86.63364955357143, "min": 86.63364955357143}}, "EndTime": 1604086560.595615, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595598}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.84662737165179, "sum": 84.84662737165179, "min": 84.84662737165179}}, "EndTime": 1604086560.595678, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595661}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 79.23879568917411, "sum": 79.23879568917411, "min": 79.23879568917411}}, "EndTime": 1604086560.595739, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595723}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 91.44746616908482, "sum": 91.44746616908482, "min": 91.44746616908482}}, "EndTime": 1604086560.595805, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595788}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 110.24767194475446, "sum": 110.24767194475446, "min": 110.24767194475446}}, "EndTime": 1604086560.595878, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.59586}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 92.14455740792411, "sum": 92.14455740792411, "min": 92.14455740792411}}, "EndTime": 1604086560.595951, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.595933}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 131.7395281110491, "sum": 131.7395281110491, "min": 131.7395281110491}}, "EndTime": 1604086560.596016, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 111.17130824497768, "sum": 111.17130824497768, "min": 111.17130824497768}}, "EndTime": 1604086560.596087, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.59607}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.06920514787946, "sum": 68.06920514787946, "min": 68.06920514787946}}, "EndTime": 1604086560.596148, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596132}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 78.58700997488839, "sum": 78.58700997488839, "min": 78.58700997488839}}, "EndTime": 1604086560.596208, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596191}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.54870169503349, "sum": 70.54870169503349, "min": 70.54870169503349}}, "EndTime": 1604086560.596245, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596235}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.60474068777901, "sum": 72.60474068777901, "min": 72.60474068777901}}, "EndTime": 1604086560.5963, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596286}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 112.22793143136161, "sum": 112.22793143136161, "min": 112.22793143136161}}, "EndTime": 1604086560.596334, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596326}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 110.40367780412946, "sum": 110.40367780412946, "min": 110.40367780412946}}, "EndTime": 1604086560.596365, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596357}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 130.33454241071428, "sum": 130.33454241071428, "min": 130.33454241071428}}, "EndTime": 1604086560.596404, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596389}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 125.34705461774554, "sum": 125.34705461774554, "min": 125.34705461774554}}, "EndTime": 1604086560.596468, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.59645}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 120.71429443359375, "sum": 120.71429443359375, "min": 120.71429443359375}}, "EndTime": 1604086560.596541, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596523}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 130.98506382533483, "sum": 130.98506382533483, "min": 130.98506382533483}}, "EndTime": 1604086560.596605, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1604086560.596589}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9606580352783203, "sum": 0.9606580352783203, "min": 0.9606580352783203}}, "EndTime": 1604086561.450747, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.450729}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9396984100341796, "sum": 0.9396984100341796, "min": 0.9396984100341796}}, "EndTime": 1604086561.450811, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.450793}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.013672866821289, "sum": 1.013672866821289, "min": 1.013672866821289}}, "EndTime": 1604086561.450872, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.450855}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8658438873291016, "sum": 0.8658438873291016, "min": 0.8658438873291016}}, "EndTime": 1604086561.450935, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.450917}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.938721923828125, "sum": 0.938721923828125, "min": 0.938721923828125}}, "EndTime": 1604086561.450998, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.450981}
#
# [10/30/2020 19:36:01 INFO 139703162902336] #quality_metric: host=algo-1, epoch=10, train mse_objective <loss>=0.610036811829
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.50492640904018, "sum": 70.50492640904018, "min": 70.50492640904018}}, "EndTime": 1604086561.502578, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.502473}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.17684936523438, "sum": 71.17684936523438, "min": 71.17684936523438}}, "EndTime": 1604086561.502706, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.502683}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 89.91927664620536, "sum": 89.91927664620536, "min": 89.91927664620536}}, "EndTime": 1604086561.502779, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.502761}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.48854718889508, "sum": 69.48854718889508, "min": 69.48854718889508}}, "EndTime": 1604086561.502839, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.502824}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.642177036830354, "sum": 45.642177036830354, "min": 45.642177036830354}}, "EndTime": 1604086561.502902, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.502885}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 46.162122453962056, "sum": 46.162122453962056, "min": 46.162122453962056}}, "EndTime": 1604086561.502967, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.502949}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.10587419782366, "sum": 49.10587419782366, "min": 49.10587419782366}}, "EndTime": 1604086561.50303, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503012}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.73809814453125, "sum": 49.73809814453125, "min": 49.73809814453125}}, "EndTime": 1604086561.503093, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503076}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 74.17843191964286, "sum": 74.17843191964286, "min": 74.17843191964286}}, "EndTime": 1604086561.503158, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503141}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 92.936279296875, "sum": 92.936279296875, "min": 92.936279296875}}, "EndTime": 1604086561.503219, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503202}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 70.56045096261161, "sum": 70.56045096261161, "min": 70.56045096261161}}, "EndTime": 1604086561.503285, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503268}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 84.48321533203125, "sum": 84.48321533203125, "min": 84.48321533203125}}, "EndTime": 1604086561.503349, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503331}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.282174246651785, "sum": 49.282174246651785, "min": 49.282174246651785}}, "EndTime": 1604086561.503412, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503397}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.09381103515625, "sum": 49.09381103515625, "min": 49.09381103515625}}, "EndTime": 1604086561.503475, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503457}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.96441214425223, "sum": 45.96441214425223, "min": 45.96441214425223}}, "EndTime": 1604086561.503536, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503521}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 48.286036900111604, "sum": 48.286036900111604, "min": 48.286036900111604}}, "EndTime": 1604086561.503599, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503581}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 77.23093087332589, "sum": 77.23093087332589, "min": 77.23093087332589}}, "EndTime": 1604086561.503664, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503646}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.08664376395089, "sum": 69.08664376395089, "min": 69.08664376395089}}, "EndTime": 1604086561.503727, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.50371}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 93.88585553850446, "sum": 93.88585553850446, "min": 93.88585553850446}}, "EndTime": 1604086561.503791, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503773}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 79.66578892299107, "sum": 79.66578892299107, "min": 79.66578892299107}}, "EndTime": 1604086561.503853, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503836}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.61148943219866, "sum": 54.61148943219866, "min": 54.61148943219866}}, "EndTime": 1604086561.503919, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.5039}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.596753801618306, "sum": 43.596753801618306, "min": 43.596753801618306}}, "EndTime": 1604086561.503981, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.503963}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.28493390764509, "sum": 47.28493390764509, "min": 47.28493390764509}}, "EndTime": 1604086561.504045, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504029}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.87276349748884, "sum": 49.87276349748884, "min": 49.87276349748884}}, "EndTime": 1604086561.504107, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.50409}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 116.37163434709821, "sum": 116.37163434709821, "min": 116.37163434709821}}, "EndTime": 1604086561.504168, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504152}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 112.08124651227679, "sum": 112.08124651227679, "min": 112.08124651227679}}, "EndTime": 1604086561.50423, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504213}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 109.12567138671875, "sum": 109.12567138671875, "min": 109.12567138671875}}, "EndTime": 1604086561.504294, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504276}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 111.49150739397321, "sum": 111.49150739397321, "min": 111.49150739397321}}, "EndTime": 1604086561.504361, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504342}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 110.23808942522321, "sum": 110.23808942522321, "min": 110.23808942522321}}, "EndTime": 1604086561.504431, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504411}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 107.18693324497768, "sum": 107.18693324497768, "min": 107.18693324497768}}, "EndTime": 1604086561.504534, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504514}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 105.81290108816964, "sum": 105.81290108816964, "min": 105.81290108816964}}, "EndTime": 1604086561.504605, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504587}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 113.78519112723214, "sum": 113.78519112723214, "min": 113.78519112723214}}, "EndTime": 1604086561.504678, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.504659}
#
# [10/30/2020 19:36:01 INFO 139703162902336] #quality_metric: host=algo-1, epoch=10, validation mse_objective <loss>=70.504926409
# [10/30/2020 19:36:01 INFO 139703162902336] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=mse_objective, value=43.5967538016
# [10/30/2020 19:36:01 INFO 139703162902336] Saving model for epoch: 10
# [10/30/2020 19:36:01 INFO 139703162902336] Saved checkpoint to "/tmp/tmpcSxqPC/mx-mod-0000.params"
# [10/30/2020 19:36:01 INFO 139703162902336] Early stop condition met. Stopping training.
# [10/30/2020 19:36:01 INFO 139703162902336] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Total Batches Seen": {"count": 1, "max": 25, "sum": 25.0, "min": 25}, "Total Records Seen": {"count": 1, "max": 2924, "sum": 2924.0, "min": 2924}, "Max Records Seen Between Resets": {"count": 1, "max": 227, "sum": 227.0, "min": 227}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1604086561.516155, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 10}, "StartTime": 1604086561.420508}
#
# [10/30/2020 19:36:01 INFO 139703162902336] #throughput_metric: host=algo-1, train throughput=2369.39201067 records/second
# [10/30/2020 19:36:01 WARNING 139703162902336] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/30/2020 19:36:01 WARNING 139703162902336] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/30/2020 19:36:01 INFO 139703162902336] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=mse_objective, value=43.5967538016
# [10/30/2020 19:36:01 INFO 139703162902336] #validation_score (algo-1) : ('mse_objective', 38.62790788922991)
# [10/30/2020 19:36:01 INFO 139703162902336] #validation_score (algo-1) : ('mse', 38.62790788922991)
# [10/30/2020 19:36:01 INFO 139703162902336] #validation_score (algo-1) : ('absolute_loss', 4.243478775024414)
# [10/30/2020 19:36:01 INFO 139703162902336] #quality_metric: host=algo-1, validation mse_objective <loss>=38.6279078892
# [10/30/2020 19:36:01 INFO 139703162902336] #quality_metric: host=algo-1, validation mse <loss>=38.6279078892
# [10/30/2020 19:36:01 INFO 139703162902336] #quality_metric: host=algo-1, validation absolute_loss <loss>=4.24347877502
# [10/30/2020 19:36:01 INFO 139703162902336] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [10/30/2020 19:36:01 INFO 139703162902336] Saved checkpoint to "/tmp/tmpAe_ma0/mx-mod-0000.params"
# [10/30/2020 19:36:01 INFO 139703162902336] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1544.8729991912842, "sum": 1544.8729991912842, "min": 1544.8729991912842}, "finalize.time": {"count": 1, "max": 83.11700820922852, "sum": 83.11700820922852, "min": 83.11700820922852}, "initialize.time": {"count": 1, "max": 158.5538387298584, "sum": 158.5538387298584, "min": 158.5538387298584}, "check_early_stopping.time": {"count": 12, "max": 1.2259483337402344, "sum": 6.359100341796875, "min": 0.15401840209960938}, "setuptime": {"count": 1, "max": 28.235912322998047, "sum": 28.235912322998047, "min": 28.235912322998047}, "update.time": {"count": 11, "max": 112.34807968139648, "sum": 1040.1513576507568, "min": 79.19597625732422}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1604086561.605856, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1604086560.270619}
#
# Training seconds: 60
# Billable seconds: 60

# %% [markdown]
# ## Step 6 (B): Deploy the trained model
#
# Similar to the XGBoost model, now that we've fit the model we need to deploy it. Also like the XGBoost model, we will use the lower level approach so that we have more control over the endpoint that gets created.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# First, we create a unique model name
linear_model_name = "boston-update-linear-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the linear-learner container that we used for training
# can also be used for inference.
linear_primary_container = {
    "Image": linear_container,
    "ModelDataUrl": linear.model_data
}

# And lastly we construct the SageMaker model
linear_model_info = session.sagemaker_client.create_model(
                                ModelName = linear_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = linear_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have the model we can start putting together the endpoint by creating an endpoint configuration.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
linear_endpoint_config_name = "boston-linear-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
linear_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = linear_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": linear_model_name,
                                "VariantName": "Linear-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = linear_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------!

# %% [markdown]
# ## Step 7 (B): Use the model
#
# Just like with the XGBoost model, we will send some data to our endpoint to make sure that it is working properly. An important note is that the output format for the linear model is different from the XGBoost model.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f6405116cc0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 19:44:37 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'd47ab6f6-dc65-407b-aff3-f723c5a4d8e2'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'd47ab6f6-dc65-407b-aff3-f723c5a4d8e2',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8")

# %%
pprint(result)
# Out:
# '{"predictions": [{"score": 23.55374526977539}]}'

# %%
Y_test.values[0]
# Out:
# array([20.9])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the Linear model's endpoint works, we can shut it down.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'a70b5460-670d-4f82-88ec-96218f6dde48',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'a70b5460-670d-4f82-88ec-96218f6dde48',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Fri, 30 Oct 2020 19:52:51 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 6 (C): Deploy a combined model
#
# So far we've constructed two separate models which we could deploy and use. Before we talk about how we can change a deployed endpoint from one configuration to another, let's consider a slightly different situation. Suppose that before we switch from using only the XGBoost model to only the Linear model, we first want to do something like an A-B test, where we send some of the incoming data to the XGBoost model and some of the data to the Linear model.
#
# Fortunately, SageMaker provides this functionality. And to actually get SageMaker to do this for us is not too different from deploying a model in the way that we've already done. The only difference is that we need to list more than one model in the production variants parameter of the endpoint configuration.
#
# A reasonable question to ask is, how much data is sent to each of the models that I list in the production variants parameter? The answer is that it depends on the weight set for each model.
#
# Suppose that we have $k$ models listed in the production variants and that each model $i$ is assigned the weight $w_i$. Then each model $i$ will receive $w_i / W$ of the traffic where $W = \sum_{i} w_i$.
#
# In our case, since we have two models, the linear model and the XGBoost model, and each model has weight 1, we see that each model will get 1 / (1 + 1) = 1/2 of the data sent to the endpoint.

# %%
# As before, we need to give our endpoint configuration a name which should be unique
combined_endpoint_config_name = "boston-combined-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
combined_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = combined_endpoint_config_name,
                            ProductionVariants = [
                                { # First we include the linear model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": linear_model_name,
                                    "VariantName": "Linear-Model"
                                }, { # And next we include the xgb model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": xgb_model_name,
                                    "VariantName": "XGB-Model"
                                }])

# %% [markdown]
# Now that we've created the endpoint configuration, we can ask SageMaker to construct the endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = combined_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------!

# %% [markdown]
# ## Step 7 (C): Use the model
#
# Now that we've constructed an endpoint which sends data to both the XGBoost model and the linear model we can send some data to the endpoint and see what sort of results we get back.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0])))
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f64064a1fd0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:27 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '977a872b-6f85-4f08-a24a-e898df842ba9'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '977a872b-6f85-4f08-a24a-e898df842ba9',
#                       'RetryAttempts': 0}}

# %% [markdown]
# Since looking at a single response doesn't give us a clear look at what is happening, we can instead take a look at a few different responses to our endpoint

# %%
for rec in range(10):
    response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[rec])))
    pprint(response)
    result = response['Body'].read().decode("utf-8")
    print(result)
    print(Y_test.values[rec])
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7f64064a78d0>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '0ce0de87-933a-406f-9791-a8ebcd9dbee9'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0ce0de87-933a-406f-9791-a8ebcd9dbee9',
#                       'RetryAttempts': 0}}
# 21.6027011871
# [20.9]
# {'Body': <botocore.response.StreamingBody object at 0x7f6405116160>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '6c71969a-82a5-4f2e-8078-4702e2e1c546'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '6c71969a-82a5-4f2e-8078-4702e2e1c546',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 23.320716857910156}]}
# [20.3]
# {'Body': <botocore.response.StreamingBody object at 0x7f6405116f60>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '0d0f08e0-2b26-4fd0-90a0-bd405e3766ef'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0d0f08e0-2b26-4fd0-90a0-bd405e3766ef',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 19.26555061340332}]}
# [17.8]
# {'Body': <botocore.response.StreamingBody object at 0x7f64051168d0>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '67c211be-2106-44e6-88e1-39a7a689c5f5'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '67c211be-2106-44e6-88e1-39a7a689c5f5',
#                       'RetryAttempts': 0}}
# 8.84943389893
# [9.7]
# {'Body': <botocore.response.StreamingBody object at 0x7f64064065c0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '0e7b1887-1497-4245-b1cb-437692f5ac50'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0e7b1887-1497-4245-b1cb-437692f5ac50',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 23.536067962646484}]}
# [20.6]
# {'Body': <botocore.response.StreamingBody object at 0x7f64064067f0>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '14766cd6-c742-48bf-98a5-b1ed460768c5'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '14766cd6-c742-48bf-98a5-b1ed460768c5',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 19.250476837158203}]}
# [15.4]
# {'Body': <botocore.response.StreamingBody object at 0x7f6406406940>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '41cca3a9-af6a-41f3-88cc-2143cee6940f'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '41cca3a9-af6a-41f3-88cc-2143cee6940f',
#                       'RetryAttempts': 0}}
# 28.4123306274
# [32.]
# {'Body': <botocore.response.StreamingBody object at 0x7f640648fba8>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '48',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '0f989e60-aef7-40e4-b070-d9b5fbf43160'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0f989e60-aef7-40e4-b070-d9b5fbf43160',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 23.949382781982422}]}
# [20.8]
# {'Body': <botocore.response.StreamingBody object at 0x7f6406406908>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '13',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': 'b25b6042-232c-4d2e-afcd-340b52af2bea'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'b25b6042-232c-4d2e-afcd-340b52af2bea',
#                       'RetryAttempts': 0}}
# 13.0539360046
# [12.]
# {'Body': <botocore.response.StreamingBody object at 0x7f6405116278>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '46',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': 'e9882c19-7625-433c-a4c3-4f5bb07f0a28'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'e9882c19-7625-433c-a4c3-4f5bb07f0a28',
#                       'RetryAttempts': 0}}
# {"predictions": [{"score": 38.2515983581543}]}
# [46.]

# %% [markdown]
# If at some point we aren't sure about the properties of a deployed endpoint, we can use the `describe_endpoint` function to get SageMaker to return a description of the deployed endpoint.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 10, 30, 19, 52, 54, 929000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-west-1:235103929652:endpoint/boston-update-endpoint-2020-10-30-19-52-54',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2020-10-30-19-52-53',
#  'EndpointName': 'boston-update-endpoint-2020-10-30-19-52-54',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2020, 10, 30, 20, 0, 11, 653000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 10, 30, 19, 52, 57, 23000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner@sha256:41e60ef0039366d7c1332b728e44d43b2693177d079b5bde332b3dfd298d9c30',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 10, 30, 19, 52, 57, 259000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost@sha256:52e3bbc5f2a9462bed15983634d6f615439afd4e81e8778337d734c93083bd5e',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1162',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-requestid': '97afcebe-5eb9-4085-bc0e-af095c7f4c54'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '97afcebe-5eb9-4085-bc0e-af095c7f4c54',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## Updating an Endpoint
#
# Now suppose that we've done our A-B test and the new linear model is working well enough. What we'd like to do now is to switch our endpoint from sending data to both the XGBoost model and the linear model to sending data only to the linear model.
#
# Of course, we don't really want to shut down the endpoint to do this as doing so would interrupt service to whoever depends on our endpoint. Instead, we can ask SageMaker to **update** an endpoint to a new endpoint configuration.
#
# What is actually happening is that SageMaker will set up a new endpoint with the new characteristics. Once this new endpoint is running, SageMaker will switch the old endpoint so that it now points at the newly deployed model, making sure that this happens seamlessly in the background.

# %%
session.sagemaker_client.update_endpoint(EndpointName=endpoint_name, EndpointConfigName=linear_endpoint_config_name)
# Out:
# {'EndpointArn': 'arn:aws:sagemaker:us-west-1:235103929652:endpoint/boston-update-endpoint-2020-10-30-19-52-54',
#  'ResponseMetadata': {'RequestId': '61d18aaf-4e90-449b-bdda-cb09cbd86075',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '61d18aaf-4e90-449b-bdda-cb09cbd86075',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '110',
#    'date': 'Fri, 30 Oct 2020 20:00:28 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# To get a glimpse at what is going on, we can ask SageMaker to describe our in-use endpoint now, before the update process has completed. When we do so, we can see that the in-use endpoint still has the same characteristics it had before.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 10, 30, 19, 52, 54, 929000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-west-1:235103929652:endpoint/boston-update-endpoint-2020-10-30-19-52-54',
#  'EndpointConfigName': 'boston-combined-endpoint-config-2020-10-30-19-52-53',
#  'EndpointName': 'boston-update-endpoint-2020-10-30-19-52-54',
#  'EndpointStatus': 'Updating',
#  'LastModifiedTime': datetime.datetime(2020, 10, 30, 20, 0, 28, 778000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 10, 30, 19, 52, 57, 23000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner@sha256:41e60ef0039366d7c1332b728e44d43b2693177d079b5bde332b3dfd298d9c30',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'},
#                         {'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 10, 30, 19, 52, 57, 259000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost@sha256:52e3bbc5f2a9462bed15983634d6f615439afd4e81e8778337d734c93083bd5e',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/xgboost:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'XGB-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '1161',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Fri, 30 Oct 2020 20:00:28 GMT',
#                                       'x-amzn-requestid': '678eefc1-bf73-4af2-9d8c-b8bfa4cdcc31'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '678eefc1-bf73-4af2-9d8c-b8bfa4cdcc31',
#                       'RetryAttempts': 0}}

# %% [markdown]
# If we now wait for the update process to complete, and then ask SageMaker to describe the endpoint, it will return the characteristics of the new endpoint configuration.

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# ---------------!

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))
# Out:
# {'CreationTime': datetime.datetime(2020, 10, 30, 19, 52, 54, 929000, tzinfo=tzlocal()),
#  'EndpointArn': 'arn:aws:sagemaker:us-west-1:235103929652:endpoint/boston-update-endpoint-2020-10-30-19-52-54',
#  'EndpointConfigName': 'boston-linear-endpoint-config-2020-10-30-19-37-04',
#  'EndpointName': 'boston-update-endpoint-2020-10-30-19-52-54',
#  'EndpointStatus': 'InService',
#  'LastModifiedTime': datetime.datetime(2020, 10, 30, 20, 7, 42, 296000, tzinfo=tzlocal()),
#  'ProductionVariants': [{'CurrentInstanceCount': 1,
#                          'CurrentWeight': 1.0,
#                          'DeployedImages': [{'ResolutionTime': datetime.datetime(2020, 10, 30, 20, 0, 31, 395000, tzinfo=tzlocal()),
#                                              'ResolvedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner@sha256:41e60ef0039366d7c1332b728e44d43b2693177d079b5bde332b3dfd298d9c30',
#                                              'SpecifiedImage': '632365934929.dkr.ecr.us-west-1.amazonaws.com/linear-learner:1'}],
#                          'DesiredInstanceCount': 1,
#                          'DesiredWeight': 1.0,
#                          'VariantName': 'Linear-Model'}],
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '770',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Fri, 30 Oct 2020 20:08:00 GMT',
#                                       'x-amzn-requestid': 'be83713a-af78-46e5-a6f7-a0662f982c1b'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'be83713a-af78-46e5-a6f7-a0662f982c1b',
#                       'RetryAttempts': 0}}

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we've finished, we need to make sure to shut down the endpoint.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir
