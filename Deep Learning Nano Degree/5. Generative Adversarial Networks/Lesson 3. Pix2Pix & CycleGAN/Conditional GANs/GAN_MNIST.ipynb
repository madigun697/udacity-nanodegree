# %% [markdown]
# # Generative Adversarial Network
# - Data: MNIST

# %%
# import libraries
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
import torch
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers)

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %%
# helper scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    x = x * (feature_range[1] - feature_range[0]) + feature_range[0]
    return x

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        self.dropout = nn.Dropout(0.3)
        
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        
        # pass x through all layers
        # apply leaky relu activation to all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.1)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.1)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.1)
        x = self.dropout(x)
        x = self.fc4(x)

        return x

class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define all layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        self.dropout = nn.Dropout(0.3)        

    def forward(self, x):
        # pass x through all layers
        x = F.leaky_relu(self.fc1(x), 0.1)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.1)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.1)
        x = self.dropout(x)
        x = self.fc4(x)        
        # final layer should have tanh applied
        x = F.tanh(x)
        
        return x

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of *last* hidden layer in the discriminator
d_hidden_size = 256

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 784
# Size of *first* hidden layer in the generator
g_hidden_size = 256

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=1024, bias=True)
#   (fc4): Linear(in_features=1024, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    # compare logits to real labels
    # smooth labels if smooth=True
    batch_size = D_out.size(0)
    
    labels = torch.ones(batch_size)*0.9 if smooth else torch.ones(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

def fake_loss(D_out):
    # compare logits to fake labels
    batch_size = D_out.size(0)
    
    labels = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

# %%
import torch.optim as optim

# learning rate for optimizers
lr = 0.0002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %%
train_on_gpu = torch.cuda.is_available()

if train_on_gpu:
    # move models to GPU
    G.cuda()
    D.cuda()
    print('GPU available for training. Models moved to GPU')
else:
    print('Training on CPU.')
# Out:
# GPU available for training. Models moved to GPU

# %%
import pickle as pkl

# training hyperparams
num_epochs = 100

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = scale(real_images)  # rescale input images from [0,1) to [-1, 1)
        if train_on_gpu:
            real_images = real_images.cuda()
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
        
        d_optimizer.zero_grad()
                
        # 1. Train with real images
        real_out = D(real_images)
        real_losses = real_loss(real_out, True)

        # Compute the discriminator losses on real images
        # use smoothed labels
        
        # 2. Train with fake images
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        if train_on_gpu:
            z = z.cuda()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images        
        fake_out = D(fake_images)
        fake_losses = fake_loss(fake_out)
        
        # add up real and fake losses and perform backprop
        d_loss = real_losses + fake_losses
        d_loss.backward()
        d_optimizer.step()
        
        
        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================
        
        g_optimizer.zero_grad()
        # 1. Train with fake images and flipped labels
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        if train_on_gpu:
            z = z.cuda()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        g_out = D(fake_images)
        
        # perform backprop
        g_loss = real_loss(g_out)
        g_loss.backward()
        g_optimizer.step()        

        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    if train_on_gpu:
        fixed_z = fixed_z.cuda()
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /home/madigun/.pyenv/versions/ml_nano/lib/python3.7/site-packages/torch/nn/functional.py:1614: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 1.3994 | g_loss: 0.6725
# Epoch [    1/  100] | d_loss: 0.4663 | g_loss: 4.1123
# Epoch [    1/  100] | d_loss: 0.7157 | g_loss: 3.3701
# Epoch [    2/  100] | d_loss: 1.0510 | g_loss: 2.0215
# Epoch [    2/  100] | d_loss: 0.4911 | g_loss: 3.8105
# Epoch [    2/  100] | d_loss: 0.7455 | g_loss: 7.1900
# Epoch [    3/  100] | d_loss: 0.4766 | g_loss: 4.5454
# Epoch [    3/  100] | d_loss: 0.7494 | g_loss: 3.5173
# Epoch [    3/  100] | d_loss: 0.4662 | g_loss: 4.2238
# Epoch [    4/  100] | d_loss: 0.6281 | g_loss: 4.8715
# Epoch [    4/  100] | d_loss: 0.6015 | g_loss: 3.9649
# Epoch [    4/  100] | d_loss: 0.5389 | g_loss: 4.7238
# Epoch [    5/  100] | d_loss: 0.6427 | g_loss: 3.9650
# Epoch [    5/  100] | d_loss: 0.5103 | g_loss: 5.9786
# Epoch [    5/  100] | d_loss: 0.5751 | g_loss: 4.1858
# Epoch [    6/  100] | d_loss: 0.6507 | g_loss: 2.1989
# Epoch [    6/  100] | d_loss: 0.5855 | g_loss: 4.4881
# Epoch [    6/  100] | d_loss: 0.6267 | g_loss: 3.8257
# Epoch [    7/  100] | d_loss: 0.7127 | g_loss: 2.2000
# Epoch [    7/  100] | d_loss: 0.6776 | g_loss: 3.0014
# Epoch [    7/  100] | d_loss: 0.7936 | g_loss: 3.0321
# Epoch [    8/  100] | d_loss: 0.9063 | g_loss: 2.9125
# Epoch [    8/  100] | d_loss: 0.6167 | g_loss: 3.9039
# Epoch [    8/  100] | d_loss: 0.7857 | g_loss: 2.7050
# Epoch [    9/  100] | d_loss: 0.8962 | g_loss: 1.7202
# Epoch [    9/  100] | d_loss: 0.6798 | g_loss: 2.1821
# Epoch [    9/  100] | d_loss: 0.7781 | g_loss: 2.1171
# Epoch [   10/  100] | d_loss: 0.9516 | g_loss: 1.5305
# Epoch [   10/  100] | d_loss: 0.7796 | g_loss: 2.8291
# Epoch [   10/  100] | d_loss: 0.8112 | g_loss: 2.7160
# Epoch [   11/  100] | d_loss: 0.9184 | g_loss: 1.6557
# Epoch [   11/  100] | d_loss: 0.7327 | g_loss: 2.3256
# Epoch [   11/  100] | d_loss: 0.7703 | g_loss: 2.4046
# Epoch [   12/  100] | d_loss: 0.9996 | g_loss: 1.8539
# Epoch [   12/  100] | d_loss: 0.7381 | g_loss: 2.7632
# Epoch [   12/  100] | d_loss: 0.8399 | g_loss: 2.3507
# Epoch [   13/  100] | d_loss: 0.9755 | g_loss: 2.7395
# Epoch [   13/  100] | d_loss: 0.9315 | g_loss: 2.1292
# Epoch [   13/  100] | d_loss: 1.0398 | g_loss: 1.4669
# Epoch [   14/  100] | d_loss: 1.0099 | g_loss: 2.8463
# Epoch [   14/  100] | d_loss: 0.9143 | g_loss: 2.2039
# Epoch [   14/  100] | d_loss: 1.1756 | g_loss: 1.8025
# Epoch [   15/  100] | d_loss: 0.9050 | g_loss: 1.7496
# Epoch [   15/  100] | d_loss: 0.8841 | g_loss: 1.6664
# Epoch [   15/  100] | d_loss: 1.0576 | g_loss: 1.5194
# Epoch [   16/  100] | d_loss: 1.0524 | g_loss: 1.7450
# Epoch [   16/  100] | d_loss: 0.9175 | g_loss: 1.5499
# Epoch [   16/  100] | d_loss: 1.1308 | g_loss: 1.5531
# Epoch [   17/  100] | d_loss: 0.9001 | g_loss: 1.8861
# Epoch [   17/  100] | d_loss: 0.8566 | g_loss: 2.3219
# Epoch [   17/  100] | d_loss: 1.1484 | g_loss: 1.9858
# Epoch [   18/  100] | d_loss: 1.1910 | g_loss: 1.4693
# Epoch [   18/  100] | d_loss: 0.9598 | g_loss: 1.8462
# Epoch [   18/  100] | d_loss: 1.0592 | g_loss: 1.6109
# Epoch [   19/  100] | d_loss: 1.1063 | g_loss: 1.6418
# Epoch [   19/  100] | d_loss: 0.9660 | g_loss: 1.7605
# Epoch [   19/  100] | d_loss: 1.1976 | g_loss: 1.8228
# Epoch [   20/  100] | d_loss: 1.1130 | g_loss: 1.6518
# Epoch [   20/  100] | d_loss: 0.9963 | g_loss: 1.6161
# Epoch [   20/  100] | d_loss: 1.3600 | g_loss: 1.4602
# Epoch [   21/  100] | d_loss: 0.9994 | g_loss: 1.8846
# Epoch [   21/  100] | d_loss: 1.0997 | g_loss: 1.2589
# Epoch [   21/  100] | d_loss: 1.1726 | g_loss: 1.5321
# Epoch [   22/  100] | d_loss: 1.1674 | g_loss: 1.5041
# Epoch [   22/  100] | d_loss: 0.9685 | g_loss: 1.3276
# Epoch [   22/  100] | d_loss: 1.1476 | g_loss: 1.6897
# Epoch [   23/  100] | d_loss: 1.3081 | g_loss: 1.6511
# Epoch [   23/  100] | d_loss: 1.0867 | g_loss: 1.3410
# Epoch [   23/  100] | d_loss: 1.2501 | g_loss: 1.4151
# Epoch [   24/  100] | d_loss: 1.1769 | g_loss: 1.9468
# Epoch [   24/  100] | d_loss: 1.1039 | g_loss: 1.1040
# Epoch [   24/  100] | d_loss: 1.1000 | g_loss: 1.3884
# Epoch [   25/  100] | d_loss: 1.1255 | g_loss: 2.0845
# Epoch [   25/  100] | d_loss: 0.7865 | g_loss: 1.7340
# Epoch [   25/  100] | d_loss: 1.1899 | g_loss: 1.5192
# Epoch [   26/  100] | d_loss: 1.2150 | g_loss: 1.6228
# Epoch [   26/  100] | d_loss: 0.9822 | g_loss: 1.5087
# Epoch [   26/  100] | d_loss: 1.2805 | g_loss: 1.5067
# Epoch [   27/  100] | d_loss: 1.0902 | g_loss: 1.6268
# Epoch [   27/  100] | d_loss: 1.1962 | g_loss: 1.0843
# Epoch [   27/  100] | d_loss: 1.3113 | g_loss: 1.2870
# Epoch [   28/  100] | d_loss: 1.0887 | g_loss: 1.6717
# Epoch [   28/  100] | d_loss: 1.2002 | g_loss: 1.2458
# Epoch [   28/  100] | d_loss: 1.1916 | g_loss: 1.1321
# Epoch [   29/  100] | d_loss: 1.1944 | g_loss: 1.7910
# Epoch [   29/  100] | d_loss: 1.1922 | g_loss: 1.2696
# Epoch [   29/  100] | d_loss: 1.3631 | g_loss: 1.5159
# Epoch [   30/  100] | d_loss: 1.1701 | g_loss: 1.3617
# Epoch [   30/  100] | d_loss: 0.9768 | g_loss: 1.5006
# Epoch [   30/  100] | d_loss: 1.2682 | g_loss: 1.4865
# Epoch [   31/  100] | d_loss: 1.0912 | g_loss: 1.7526
# Epoch [   31/  100] | d_loss: 1.1061 | g_loss: 1.1373
# Epoch [   31/  100] | d_loss: 1.2428 | g_loss: 1.3502
# Epoch [   32/  100] | d_loss: 1.2228 | g_loss: 1.0100
# Epoch [   32/  100] | d_loss: 1.0005 | g_loss: 1.4169
# Epoch [   32/  100] | d_loss: 1.4501 | g_loss: 1.0246
# Epoch [   33/  100] | d_loss: 1.3504 | g_loss: 1.1780
# Epoch [   33/  100] | d_loss: 0.9613 | g_loss: 1.4752
# Epoch [   33/  100] | d_loss: 1.3867 | g_loss: 1.2370
# Epoch [   34/  100] | d_loss: 1.3374 | g_loss: 1.0848
# Epoch [   34/  100] | d_loss: 1.0455 | g_loss: 1.3673
# Epoch [   34/  100] | d_loss: 1.4849 | g_loss: 1.0797
# Epoch [   35/  100] | d_loss: 1.2410 | g_loss: 1.0910
# Epoch [   35/  100] | d_loss: 1.1736 | g_loss: 1.3289
# Epoch [   35/  100] | d_loss: 1.1066 | g_loss: 1.4290
# Epoch [   36/  100] | d_loss: 1.3379 | g_loss: 2.1303
# Epoch [   36/  100] | d_loss: 1.0958 | g_loss: 1.2581
# Epoch [   36/  100] | d_loss: 1.5565 | g_loss: 1.2364
# Epoch [   37/  100] | d_loss: 1.2784 | g_loss: 1.1367
# Epoch [   37/  100] | d_loss: 1.0829 | g_loss: 1.2283
# Epoch [   37/  100] | d_loss: 1.1966 | g_loss: 1.5478
# Epoch [   38/  100] | d_loss: 1.1954 | g_loss: 1.7434
# Epoch [   38/  100] | d_loss: 1.3319 | g_loss: 1.2669
# Epoch [   38/  100] | d_loss: 1.3382 | g_loss: 1.3868
# Epoch [   39/  100] | d_loss: 1.2954 | g_loss: 1.3695
# Epoch [   39/  100] | d_loss: 1.3916 | g_loss: 1.1777
# Epoch [   39/  100] | d_loss: 1.1721 | g_loss: 1.3053
# Epoch [   40/  100] | d_loss: 1.2651 | g_loss: 1.3211
# Epoch [   40/  100] | d_loss: 1.1458 | g_loss: 1.0053
# Epoch [   40/  100] | d_loss: 1.3492 | g_loss: 1.2551
# Epoch [   41/  100] | d_loss: 1.3949 | g_loss: 1.3050
# Epoch [   41/  100] | d_loss: 1.2321 | g_loss: 1.2201
# Epoch [   41/  100] | d_loss: 1.4062 | g_loss: 1.1449
# Epoch [   42/  100] | d_loss: 1.3375 | g_loss: 1.1213
# Epoch [   42/  100] | d_loss: 1.1171 | g_loss: 1.4844
# Epoch [   42/  100] | d_loss: 1.1609 | g_loss: 1.1688
# Epoch [   43/  100] | d_loss: 1.3242 | g_loss: 1.1992
# Epoch [   43/  100] | d_loss: 1.1525 | g_loss: 1.0405
# Epoch [   43/  100] | d_loss: 1.3049 | g_loss: 1.0298
# Epoch [   44/  100] | d_loss: 1.2358 | g_loss: 1.3691
# Epoch [   44/  100] | d_loss: 1.1489 | g_loss: 1.1898
# Epoch [   44/  100] | d_loss: 1.3872 | g_loss: 1.3785
# Epoch [   45/  100] | d_loss: 1.2744 | g_loss: 1.5925
# Epoch [   45/  100] | d_loss: 1.1538 | g_loss: 1.3430
# Epoch [   45/  100] | d_loss: 1.4583 | g_loss: 1.0152
# Epoch [   46/  100] | d_loss: 1.1918 | g_loss: 1.4983
# Epoch [   46/  100] | d_loss: 1.1088 | g_loss: 1.2008
# Epoch [   46/  100] | d_loss: 1.3400 | g_loss: 1.1618
# Epoch [   47/  100] | d_loss: 1.2216 | g_loss: 1.5156
# Epoch [   47/  100] | d_loss: 1.2199 | g_loss: 1.1952
# Epoch [   47/  100] | d_loss: 1.4031 | g_loss: 1.6557
# Epoch [   48/  100] | d_loss: 1.1454 | g_loss: 1.3627
# Epoch [   48/  100] | d_loss: 1.3294 | g_loss: 1.2801
# Epoch [   48/  100] | d_loss: 1.1419 | g_loss: 1.2079
# Epoch [   49/  100] | d_loss: 1.1800 | g_loss: 1.2876
# Epoch [   49/  100] | d_loss: 1.0938 | g_loss: 1.2738
# Epoch [   49/  100] | d_loss: 1.3575 | g_loss: 0.8197
# Epoch [   50/  100] | d_loss: 1.2202 | g_loss: 0.9881
# Epoch [   50/  100] | d_loss: 1.2434 | g_loss: 1.2213
# Epoch [   50/  100] | d_loss: 1.3889 | g_loss: 0.9528
# Epoch [   51/  100] | d_loss: 1.1920 | g_loss: 1.5540
# Epoch [   51/  100] | d_loss: 1.2149 | g_loss: 1.1279
# Epoch [   51/  100] | d_loss: 1.3965 | g_loss: 1.1600
# Epoch [   52/  100] | d_loss: 1.2476 | g_loss: 1.4436
# Epoch [   52/  100] | d_loss: 1.1589 | g_loss: 1.2456
# Epoch [   52/  100] | d_loss: 1.3315 | g_loss: 1.1262
# Epoch [   53/  100] | d_loss: 1.3820 | g_loss: 0.9676
# Epoch [   53/  100] | d_loss: 1.2044 | g_loss: 1.4332
# Epoch [   53/  100] | d_loss: 1.5246 | g_loss: 0.8074
# Epoch [   54/  100] | d_loss: 1.2516 | g_loss: 1.3851
# Epoch [   54/  100] | d_loss: 1.3049 | g_loss: 1.0908
# Epoch [   54/  100] | d_loss: 1.3112 | g_loss: 1.1303
# Epoch [   55/  100] | d_loss: 1.1715 | g_loss: 1.6573
# Epoch [   55/  100] | d_loss: 1.0387 | g_loss: 1.4825
# Epoch [   55/  100] | d_loss: 1.3662 | g_loss: 1.0982
# Epoch [   56/  100] | d_loss: 1.1556 | g_loss: 1.5861
# Epoch [   56/  100] | d_loss: 1.1437 | g_loss: 1.2821
# Epoch [   56/  100] | d_loss: 1.3987 | g_loss: 0.8870
# Epoch [   57/  100] | d_loss: 1.3210 | g_loss: 1.0789
# Epoch [   57/  100] | d_loss: 1.1526 | g_loss: 1.1020
# Epoch [   57/  100] | d_loss: 1.2255 | g_loss: 1.1660
# Epoch [   58/  100] | d_loss: 1.1433 | g_loss: 1.6479
# Epoch [   58/  100] | d_loss: 1.3966 | g_loss: 1.0203
# Epoch [   58/  100] | d_loss: 1.2122 | g_loss: 1.3445
# Epoch [   59/  100] | d_loss: 1.1808 | g_loss: 1.3121
# Epoch [   59/  100] | d_loss: 1.3210 | g_loss: 1.3484
# Epoch [   59/  100] | d_loss: 1.2722 | g_loss: 1.0025
# Epoch [   60/  100] | d_loss: 1.2717 | g_loss: 1.6980
# Epoch [   60/  100] | d_loss: 1.2414 | g_loss: 1.2496
# Epoch [   60/  100] | d_loss: 1.4154 | g_loss: 1.0421
# Epoch [   61/  100] | d_loss: 1.2666 | g_loss: 1.2443
# Epoch [   61/  100] | d_loss: 1.1581 | g_loss: 1.0997
# Epoch [   61/  100] | d_loss: 1.2011 | g_loss: 1.2285
# Epoch [   62/  100] | d_loss: 1.0651 | g_loss: 1.1859
# Epoch [   62/  100] | d_loss: 1.2568 | g_loss: 1.2357
# Epoch [   62/  100] | d_loss: 1.3138 | g_loss: 1.1649
# Epoch [   63/  100] | d_loss: 1.3432 | g_loss: 1.2760
# Epoch [   63/  100] | d_loss: 1.2011 | g_loss: 1.3641
# Epoch [   63/  100] | d_loss: 1.2592 | g_loss: 0.9577
# Epoch [   64/  100] | d_loss: 1.2485 | g_loss: 1.1571
# Epoch [   64/  100] | d_loss: 1.3835 | g_loss: 1.0953
# Epoch [   64/  100] | d_loss: 1.2110 | g_loss: 1.0837
# Epoch [   65/  100] | d_loss: 1.3082 | g_loss: 1.2590
# Epoch [   65/  100] | d_loss: 1.1251 | g_loss: 1.1276
# Epoch [   65/  100] | d_loss: 1.2174 | g_loss: 1.2733
# Epoch [   66/  100] | d_loss: 1.1251 | g_loss: 1.3762
# Epoch [   66/  100] | d_loss: 1.2910 | g_loss: 1.1665
# Epoch [   66/  100] | d_loss: 1.4273 | g_loss: 1.2184
# Epoch [   67/  100] | d_loss: 1.2350 | g_loss: 1.3352
# Epoch [   67/  100] | d_loss: 1.1023 | g_loss: 1.3907
# Epoch [   67/  100] | d_loss: 1.1820 | g_loss: 1.2816
# Epoch [   68/  100] | d_loss: 1.2395 | g_loss: 1.4271
# Epoch [   68/  100] | d_loss: 1.2649 | g_loss: 1.3184
# Epoch [   68/  100] | d_loss: 1.2387 | g_loss: 1.1503
# Epoch [   69/  100] | d_loss: 1.2529 | g_loss: 1.3260
# Epoch [   69/  100] | d_loss: 1.2333 | g_loss: 1.4283
# Epoch [   69/  100] | d_loss: 1.2179 | g_loss: 1.1611
# Epoch [   70/  100] | d_loss: 1.3450 | g_loss: 1.4225
# Epoch [   70/  100] | d_loss: 1.0945 | g_loss: 1.3018
# Epoch [   70/  100] | d_loss: 1.5467 | g_loss: 0.8938
# Epoch [   71/  100] | d_loss: 1.1961 | g_loss: 1.5250
# Epoch [   71/  100] | d_loss: 1.3019 | g_loss: 1.2597
# Epoch [   71/  100] | d_loss: 1.2888 | g_loss: 1.0207
# Epoch [   72/  100] | d_loss: 1.1626 | g_loss: 2.0612
# Epoch [   72/  100] | d_loss: 1.1510 | g_loss: 1.0614
# Epoch [   72/  100] | d_loss: 1.3962 | g_loss: 1.2294
# Epoch [   73/  100] | d_loss: 1.1800 | g_loss: 1.3258
# Epoch [   73/  100] | d_loss: 1.0254 | g_loss: 1.3939
# Epoch [   73/  100] | d_loss: 1.3492 | g_loss: 1.2290
# Epoch [   74/  100] | d_loss: 1.1634 | g_loss: 1.4866
# Epoch [   74/  100] | d_loss: 1.3289 | g_loss: 1.3299
# Epoch [   74/  100] | d_loss: 1.3287 | g_loss: 1.1094
# Epoch [   75/  100] | d_loss: 1.2263 | g_loss: 1.2517
# Epoch [   75/  100] | d_loss: 1.0488 | g_loss: 1.5038
# Epoch [   75/  100] | d_loss: 1.2993 | g_loss: 1.0789
# Epoch [   76/  100] | d_loss: 1.3415 | g_loss: 1.1184
# Epoch [   76/  100] | d_loss: 1.1484 | g_loss: 1.3159
# Epoch [   76/  100] | d_loss: 1.1990 | g_loss: 1.2478
# Epoch [   77/  100] | d_loss: 1.1952 | g_loss: 1.4243
# Epoch [   77/  100] | d_loss: 1.1419 | g_loss: 1.2243
# Epoch [   77/  100] | d_loss: 1.3116 | g_loss: 1.1958
# Epoch [   78/  100] | d_loss: 1.1410 | g_loss: 1.3053
# Epoch [   78/  100] | d_loss: 1.1955 | g_loss: 1.3818
# Epoch [   78/  100] | d_loss: 1.2987 | g_loss: 1.2353
# Epoch [   79/  100] | d_loss: 1.1922 | g_loss: 1.6023
# Epoch [   79/  100] | d_loss: 1.1312 | g_loss: 1.4227
# Epoch [   79/  100] | d_loss: 1.3261 | g_loss: 1.0191
# Epoch [   80/  100] | d_loss: 1.2005 | g_loss: 1.3586
# Epoch [   80/  100] | d_loss: 1.1417 | g_loss: 1.3453
# Epoch [   80/  100] | d_loss: 1.4436 | g_loss: 1.0406
# Epoch [   81/  100] | d_loss: 1.1544 | g_loss: 1.2349
# Epoch [   81/  100] | d_loss: 1.2432 | g_loss: 1.1660
# Epoch [   81/  100] | d_loss: 1.2674 | g_loss: 1.1276
# Epoch [   82/  100] | d_loss: 1.2182 | g_loss: 1.3587
# Epoch [   82/  100] | d_loss: 1.1929 | g_loss: 1.2372
# Epoch [   82/  100] | d_loss: 1.2837 | g_loss: 1.0284
# Epoch [   83/  100] | d_loss: 1.2202 | g_loss: 1.5703
# Epoch [   83/  100] | d_loss: 1.1442 | g_loss: 1.2695
# Epoch [   83/  100] | d_loss: 1.4080 | g_loss: 1.0062
# Epoch [   84/  100] | d_loss: 1.0683 | g_loss: 1.4467
# Epoch [   84/  100] | d_loss: 1.0882 | g_loss: 1.2337
# Epoch [   84/  100] | d_loss: 1.2107 | g_loss: 1.2309
# Epoch [   85/  100] | d_loss: 1.2906 | g_loss: 1.2125
# Epoch [   85/  100] | d_loss: 1.0541 | g_loss: 1.4184
# Epoch [   85/  100] | d_loss: 1.2389 | g_loss: 1.3945
# Epoch [   86/  100] | d_loss: 1.2708 | g_loss: 1.4827
# Epoch [   86/  100] | d_loss: 1.2465 | g_loss: 1.1562
# Epoch [   86/  100] | d_loss: 1.3003 | g_loss: 1.2503
# Epoch [   87/  100] | d_loss: 1.1669 | g_loss: 1.2405
# Epoch [   87/  100] | d_loss: 1.2639 | g_loss: 1.3336
# Epoch [   87/  100] | d_loss: 1.3200 | g_loss: 1.2590
# Epoch [   88/  100] | d_loss: 1.1232 | g_loss: 1.2840
# Epoch [   88/  100] | d_loss: 1.1424 | g_loss: 1.3013
# Epoch [   88/  100] | d_loss: 1.3257 | g_loss: 1.2654
# Epoch [   89/  100] | d_loss: 1.1759 | g_loss: 1.6637
# Epoch [   89/  100] | d_loss: 1.0408 | g_loss: 1.3305
# Epoch [   89/  100] | d_loss: 1.3273 | g_loss: 1.0206
# Epoch [   90/  100] | d_loss: 1.2606 | g_loss: 1.2873
# Epoch [   90/  100] | d_loss: 1.1284 | g_loss: 1.2293
# Epoch [   90/  100] | d_loss: 1.4681 | g_loss: 1.1731
# Epoch [   91/  100] | d_loss: 1.1722 | g_loss: 1.1477
# Epoch [   91/  100] | d_loss: 1.1069 | g_loss: 1.3980
# Epoch [   91/  100] | d_loss: 1.2949 | g_loss: 1.0618
# Epoch [   92/  100] | d_loss: 1.1351 | g_loss: 1.3856
# Epoch [   92/  100] | d_loss: 1.1646 | g_loss: 1.1838
# Epoch [   92/  100] | d_loss: 1.3710 | g_loss: 1.1843
# Epoch [   93/  100] | d_loss: 1.3916 | g_loss: 1.5007
# Epoch [   93/  100] | d_loss: 1.2203 | g_loss: 1.2094
# Epoch [   93/  100] | d_loss: 1.3468 | g_loss: 1.1345
# Epoch [   94/  100] | d_loss: 1.3224 | g_loss: 1.2662
# Epoch [   94/  100] | d_loss: 1.1936 | g_loss: 1.1798
# Epoch [   94/  100] | d_loss: 1.2447 | g_loss: 1.2498
# Epoch [   95/  100] | d_loss: 1.1416 | g_loss: 1.1977
# Epoch [   95/  100] | d_loss: 1.1968 | g_loss: 1.2165
# Epoch [   95/  100] | d_loss: 1.2273 | g_loss: 1.3302
# Epoch [   96/  100] | d_loss: 1.2397 | g_loss: 1.5292
# Epoch [   96/  100] | d_loss: 1.1645 | g_loss: 1.3797
# Epoch [   96/  100] | d_loss: 1.2515 | g_loss: 1.3491
# Epoch [   97/  100] | d_loss: 1.1128 | g_loss: 1.2544
# Epoch [   97/  100] | d_loss: 1.2742 | g_loss: 1.2899
# Epoch [   97/  100] | d_loss: 1.1336 | g_loss: 1.2882
# Epoch [   98/  100] | d_loss: 1.2012 | g_loss: 1.3548
# Epoch [   98/  100] | d_loss: 1.1700 | g_loss: 1.3145
# Epoch [   98/  100] | d_loss: 1.2617 | g_loss: 1.2165
# Epoch [   99/  100] | d_loss: 1.3280 | g_loss: 1.2876
# Epoch [   99/  100] | d_loss: 1.1920 | g_loss: 1.3168
# Epoch [   99/  100] | d_loss: 1.1748 | g_loss: 1.3196
# Epoch [  100/  100] | d_loss: 1.1566 | g_loss: 1.4243
# Epoch [  100/  100] | d_loss: 1.2117 | g_loss: 1.0582
# Epoch [  100/  100] | d_loss: 1.2223 | g_loss: 1.1343

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        if train_on_gpu:
            img = img.cpu()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)
